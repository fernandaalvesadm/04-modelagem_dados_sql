# %% [markdown]
# # Pipelines e ETL com Python

# %% [markdown]
# ## 1. O problema
#
# Começamos com:
#
# `vendas.csv`
#
# E queremos chegar em:
#
# `vendas.db`
#
# ### Fluxo
#
# ```text
# CSV
#  ↓
# EXTRACT
#  ↓
# TRANSFORM
#  ↓
# LOAD
#  ↓
# SQLite

# %%
import pandas as pd

dados = {
    "data": [
        "2026-08-01", "2026-08-01", "2026-08-02", "2026-08-02",
        "2026-08-03", "2026-08-03", "2026-08-04", "2026-08-04",
        "2026-08-05", "2026-08-05", "2026-08-06", "2026-08-06",
        "2026-08-07", "2026-08-07", "2026-08-08", "2026-08-08",
        "2026-08-09", "2026-08-09", "2026-08-10", "2026-08-10",
        "2026-08-11", "2026-08-11", "2026-08-12", "2026-08-12",
        "2026-08-13", "2026-08-13", "2026-08-14", "2026-08-14",
        "2026-08-15", "2026-08-15", "2026-08-16", "2026-08-16",
        "2026-08-17", "2026-08-17", "2026-08-18", "2026-08-18",
        "2026-08-19", "2026-08-19", "2026-08-20", "2026-08-20",
        "2026-08-21", "2026-08-21", "2026-08-22", "2026-08-22",
        "2026-08-23", "2026-08-23", "2026-08-24", "2026-08-24",
        "2026-08-25", "2026-08-25"
    ],
    "produto": [
        "Notebook", "Mouse", "Teclado", "Monitor",
        "Notebook", "Mouse", "Headset", "Teclado",
        "Monitor", "Mouse", "Notebook", "Headset",
        "Teclado", "Monitor", "Mouse", "Notebook",
        "Headset", "Teclado", "Monitor", "Mouse",
        "Notebook", "Headset", "Teclado", "Mouse",
        "Monitor", "Notebook", "Headset", "Teclado",
        "Mouse", "Monitor", "Notebook", "Headset",
        "Teclado", "Mouse", "Monitor", "Notebook",
        "Headset", "Teclado", "Mouse", "Monitor",
        "Notebook", "Headset", "Teclado", "Mouse",
        "Monitor", "Notebook", "Headset", "Teclado",
        "Mouse", "Monitor"
    ],
    "quantidade": [
        2, 5, 3, 1, 1, 8, 4, 2, 3, 6,
        2, 3, 5, 1, 10, 1, 4, 3, 2, 7,
        2, 5, 4, 8, 1, 2, 3, 6, 9, 2,
        1, 4, 3, 7, 2, 1, 5, 4, 6, 2,
        1, 3, 5, 8, 2, 1, 4, 3, 7, 2
    ],
    "valor_unitario": [
        3500, 80, 150, 1200, 3500, 80, 250, 150, 1200, 80,
        3500, 250, 150, 1200, 80, 3500, 250, 150, 1200, 80,
        3500, 250, 150, 80, 1200, 3500, 250, 150, 80, 1200,
        3500, 250, 150, 80, 1200, 3500, 250, 150, 80, 1200,
        3500, 250, 150, 80, 1200, 3500, 250, 150, 80, 1200
    ]
}

df = pd.DataFrame(dados)

df.to_csv("dados/vendas.csv", index=False)

print("vendas.csv criado com sucesso!")
# Out:
# vendas.csv criado com sucesso!

# %% [markdown]
# ## 2. ETL

# %%
# Importação das bibliotecas
import pandas as pd
import sqlite3

# %% [markdown]
# ### Extract

# %%
df = pd.read_csv("dados/vendas.csv")

# %%
df
# Out:
#           data   produto  quantidade  valor_unitario
# 0   2026-08-01  Notebook           2            3500
# 1   2026-08-01     Mouse           5              80
# 2   2026-08-02   Teclado           3             150
# 3   2026-08-02   Monitor           1            1200
# 4   2026-08-03  Notebook           1            3500
# 5   2026-08-03     Mouse           8              80
# 6   2026-08-04   Headset           4             250
# 7   2026-08-04   Teclado           2             150
# 8   2026-08-05   Monitor           3            1200
# 9   2026-08-05     Mouse           6              80
# 10  2026-08-06  Notebook           2            3500
# 11  2026-08-06   Headset           3             250
# 12  2026-08-07   Teclado           5             150
# 13  2026-08-07   Monitor           1            1200
# 14  2026-08-08     Mouse          10              80
# 15  2026-08-08  Notebook           1            3500
# 16  2026-08-09   Headset           4             250
# 17  2026-08-09   Teclado           3             150
# 18  2026-08-10   Monitor           2            1200
# 19  2026-08-10     Mouse           7              80
# 20  2026-08-11  Notebook           2            3500
# 21  2026-08-11   Headset           5             250
# 22  2026-08-12   Teclado           4             150
# 23  2026-08-12     Mouse           8              80
# 24  2026-08-13   Monitor           1            1200
# 25  2026-08-13  Notebook           2            3500
# 26  2026-08-14   Headset           3             250
# 27  2026-08-14   Teclado           6             150
# 28  2026-08-15     Mouse           9              80
# 29  2026-08-15   Monitor           2            1200
# 30  2026-08-16  Notebook           1            3500
# 31  2026-08-16   Headset           4             250
# 32  2026-08-17   Teclado           3             150
# 33  2026-08-17     Mouse           7              80
# 34  2026-08-18   Monitor           2            1200
# 35  2026-08-18  Notebook           1            3500
# 36  2026-08-19   Headset           5             250
# 37  2026-08-19   Teclado           4             150
# 38  2026-08-20     Mouse           6              80
# 39  2026-08-20   Monitor           2            1200
# 40  2026-08-21  Notebook           1            3500
# 41  2026-08-21   Headset           3             250
# 42  2026-08-22   Teclado           5             150
# 43  2026-08-22     Mouse           8              80
# 44  2026-08-23   Monitor           2            1200
# 45  2026-08-23  Notebook           1            3500
# 46  2026-08-24   Headset           4             250
# 47  2026-08-24   Teclado           3             150
# 48  2026-08-25     Mouse           7              80
# 49  2026-08-25   Monitor           2            1200

# %% [markdown]
# ### Transform

# %%
df["data"] = pd.to_datetime(df["data"])

df["valor_total"] = (
    df["quantidade"] *
    df["valor_unitario"]
)

# %%
df
# Out:
#          data   produto  quantidade  valor_unitario  valor_total
# 0  2026-08-01  Notebook           2            3500         7000
# 1  2026-08-01     Mouse           5              80          400
# 2  2026-08-02   Teclado           3             150          450
# 3  2026-08-02   Monitor           1            1200         1200
# 4  2026-08-03  Notebook           1            3500         3500
# 5  2026-08-03     Mouse           8              80          640
# 6  2026-08-04   Headset           4             250         1000
# 7  2026-08-04   Teclado           2             150          300
# 8  2026-08-05   Monitor           3            1200         3600
# 9  2026-08-05     Mouse           6              80          480
# 10 2026-08-06  Notebook           2            3500         7000
# 11 2026-08-06   Headset           3             250          750
# 12 2026-08-07   Teclado           5             150          750
# 13 2026-08-07   Monitor           1            1200         1200
# 14 2026-08-08     Mouse          10              80          800
# 15 2026-08-08  Notebook           1            3500         3500
# 16 2026-08-09   Headset           4             250         1000
# 17 2026-08-09   Teclado           3             150          450
# 18 2026-08-10   Monitor           2            1200         2400
# 19 2026-08-10     Mouse           7              80          560
# 20 2026-08-11  Notebook           2            3500         7000
# 21 2026-08-11   Headset           5             250         1250
# 22 2026-08-12   Teclado           4             150          600
# 23 2026-08-12     Mouse           8              80          640
# 24 2026-08-13   Monitor           1            1200         1200
# 25 2026-08-13  Notebook           2            3500         7000
# 26 2026-08-14   Headset           3             250          750
# 27 2026-08-14   Teclado           6             150          900
# 28 2026-08-15     Mouse           9              80          720
# 29 2026-08-15   Monitor           2            1200         2400
# 30 2026-08-16  Notebook           1            3500         3500
# 31 2026-08-16   Headset           4             250         1000
# 32 2026-08-17   Teclado           3             150          450
# 33 2026-08-17     Mouse           7              80          560
# 34 2026-08-18   Monitor           2            1200         2400
# 35 2026-08-18  Notebook           1            3500         3500
# 36 2026-08-19   Headset           5             250         1250
# 37 2026-08-19   Teclado           4             150          600
# 38 2026-08-20     Mouse           6              80          480
# 39 2026-08-20   Monitor           2            1200         2400
# 40 2026-08-21  Notebook           1            3500         3500
# 41 2026-08-21   Headset           3             250          750
# 42 2026-08-22   Teclado           5             150          750
# 43 2026-08-22     Mouse           8              80          640
# 44 2026-08-23   Monitor           2            1200         2400
# 45 2026-08-23  Notebook           1            3500         3500
# 46 2026-08-24   Headset           4             250         1000
# 47 2026-08-24   Teclado           3             150          450
# 48 2026-08-25     Mouse           7              80          560
# 49 2026-08-25   Monitor           2            1200         2400

# %% [markdown]
# ### Load

# %%
#df.to_sql(...)

# %%
# Cria/conecta ao banco SQLite
conexao = sqlite3.connect("dados/vendas.db")

# Envia o DataFrame para uma tabela do banco
df.to_sql(
    "vendas",
    conexao,
    if_exists="replace",
    index=False
)

# Fecha a conexão
conexao.close()


print("ETL concluído com sucesso!")
# Out:
# ETL concluído com sucesso!

# %% [markdown]
# > O que acontece no to_sql()?
#  - "vendas" - nome da tabela dentro do banco
#  - conexao - conexão com o SQLite
#  - if_exists="replace" - substitui a tabela se ela já existir
#  - index=False - não cria uma coluna para o índice do Pandas

# %% [markdown]
# ## 3. Funções reutilizáveis

# %% [markdown]
# #### Em vez de deixar tudo solto:
#  - df["valor_total"] = ...
#  - Uma função permite transformar uma operação que pode ser repetida em uma unidade reutilizável.

# %%
def calcular_valor_total(df):
    df["valor_total"] = (
        df["quantidade"] *
        df["valor_unitario"]
    )

    return df

# %%
df = calcular_valor_total(df)

# %% [markdown]
# #### ou...
# O apply() vai executar a função linha por linha:

# %% [markdown]
# def calcular_valor_total(linha):
#     return linha["quantidade"] * linha["valor_unitario"]
#
#
# df["valor_total"] = df.apply(calcular_valor_total, axis=1)

# %% [markdown]
# ## 4. Funções de ETL

# %%
def extrair_dados():
    ...

def transformar_dados(df):
    ...

def carregar_dados(df):
    ...

# %%
df = extrair_dados()

df = transformar_dados(df)

carregar_dados(df)

# %% [markdown]
# ## 5. Classes
# - Uma classe pode ajudar a organizar informações e comportamentos que pertencem ao mesmo processo.

# %% [markdown]
# - > Não vamos estudar **POO** profundamente agora.
# - > O objetivo é apenas entender que classes podem ajudar a organizar pipelines maiores.

# %%
arquivo = "vendas.csv"
banco = "vendas.db"
tabela = "vendas"

# %%
class PipelineVendas:

    def __init__(self, arquivo, banco):
        self.arquivo = arquivo
        self.banco = banco

    def extrair(self):
        ...

    def transformar(self):
        ...

    def carregar(self):
        ...

# %% [markdown]
# - O **__init__** é um método especial executado automaticamente quando o objeto é criado.
# - __init__ não é obrigatório em uma classe Python.
# - Usar o __init__ quando precisa configurar alguma coisa no momento em que o objeto é criado. Exemplo: O __init__ recebe "vendas.csv" e guarda no objeto para ser usado em um método.
#
# - **self** representa o próprio objeto criado a partir da classe.
# - O **self** permite acessar atributos e métodos daquele objeto.

# %% [markdown]
# ## 6. SQLite

# %%
# Importação da biblioteca ( não execultar, apenas para referência)
import sqlite3

# %%
# Criar conexão ( não execultar, apenas para referência)
conexao = sqlite3.connect("dados/vendas.db")

# %%
# Carregar
df.to_sql(
    "vendas",
    conexao,
    if_exists="replace",
    index=False
)

# %%
# CONSULTAR ( Deu erro por que fechamos a conexão)
resultado = pd.read_sql(
    "SELECT * FROM vendas",
    conexao
)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[8], line 2
#       1 # CONSULTAR
# ----> 2 resultado = pd.read_sql(
#       3     "SELECT * FROM vendas",
#       4     conexao
#       5 )
#
# File c:\Users\Fernanda Alvez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
#     701     if isinstance(pandas_sql, SQLiteDatabase):
# --> 702         return pandas_sql.read_query(
#     703             sql,
#     704             index_col=index_col,
#     705             params=params,
#     706             coerce_float=coerce_float,
#     707             parse_dates=parse_dates,
#     708             chunksize=chunksize,
#     709             dtype_backend=dtype_backend,
#     710             dtype=dtype,
#     711         )
#     713     try:
#     714         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\Fernanda Alvez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:2809, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2798 def read_query(
#    2799     self,
#    2800     sql,
#    (...)   2807     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2808 ) -> DataFrame | Iterator[DataFrame]:
# -> 2809     cursor = self.execute(sql, params)
#    2810     columns = [col_desc[0] for col_desc in cursor.description]
#    2812     if chunksize is not None:
#
# File c:\Users\Fernanda Alvez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:2743, in SQLiteDatabase.execute(self, sql, params)
#    2741     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2742 args = [] if params is None else [params]
# -> 2743 cur = self.con.cursor()
#    2744 try:
#    2745     cur.execute(sql, *args)
#
# ProgrammingError: Cannot operate on a closed database.

# %%
resultado

# %% [markdown]
# ### Python pode enviar dados para um banco SQL e também consultar dados armazenados nele.

# %% [markdown]
# ## 7. Pipeline completo

# %%
import pandas as pd
import sqlite3


def extrair_dados():
    return pd.read_csv("dados/vendas.csv")


def transformar_dados(df):

    df["data"] = pd.to_datetime(df["data"])

    df["valor_total"] = (
        df["quantidade"] *
        df["valor_unitario"]
    )

    return df


def carregar_dados(df):

    conexao = sqlite3.connect("dados/vendas_1.db")

    df.to_sql(
        "vendas",
        conexao,
        if_exists="replace",
        index=False
    )

    conexao.close()


# ----------------------------------------
# ETL - Execução
# ----------------------------------------

df = extrair_dados()
df = transformar_dados(df)
carregar_dados(df)

# %% [markdown]
# ## PIPELINE
#
# ```text
# vendas.csv
#     │
#     ▼
#  EXTRACT
#     │
#     ▼
#   Pandas
#     │
#     ▼
# TRANSFORM
#     │
#     ▼
#   Pandas
#     │
#     ▼
#    LOAD
#     │
#     ▼
#  SQLite
#     │
#     ▼
#  vendas.db

# %% [markdown]
# ### Pipeline completo (usando Classes)

# %%
import pandas as pd
import sqlite3

# Criação da classe
class PipelineVendas:

    # Método extrair
    def extrair(self):
        return pd.read_csv("dados/vendas.csv")

    # Método transformar
    def transformar(self, df):

        df["data"] = pd.to_datetime(df["data"])

        df["valor_total"] = (
            df["quantidade"] *
            df["valor_unitario"]
        )

        return df
    # Método carregar
    def carregar(self, df):

        conexao = sqlite3.connect("dados/vendas_2.db")

        df.to_sql(
            "vendas",
            conexao,
            if_exists="replace",
            index=False
        )

        conexao.close()

    # Função para executar o ETL (ordem)
    def executar(self):

        df = self.extrair()

        df = self.transformar(df)

        self.carregar(df)


# Agrupa tudo que é necessário para o ETL
# Cria um objeto da classe PipelineVendas
pipeline = PipelineVendas()

# Executar pipeline
# Chama o método executar() do objeto pipeline.
pipeline.executar()

# %% [markdown]
# - PipelineVendas() cria o pipeline.
# - pipeline.executar() manda o pipeline executar todas as etapas do ETL.

# %% [markdown]
# #### Pipeline ETL com Classes
#
# A ideia é utilizar uma classe para **organizar as etapas do ETL** em um único lugar.
#
# ##### Organização da classe
#
#     PipelineVendas
#     │
#     ├── extrair()
#     │      ↓
#     │   vendas.csv
#     │
#     ├── transformar()
#     │      ↓
#     │   Pandas
#     │
#     ├── carregar()
#     │      ↓
#     │   vendas.db
#     │
#     └── executar()
#            ↓
#        coordena o ETL
#
# ##### Método `executar()`
#
# O ponto mais importante para os alunos é o método `executar()`:
#
#     def executar(self):
#
#         df = self.extrair()
#
#         df = self.transformar(df)
#
#         self.carregar(df)
#
# O método `executar()` funciona como o **orquestrador do processo**, coordenando as etapas do ETL:
#
#     EXTRACT
#        ↓
#     TRANSFORM
#        ↓
#     LOAD
#
# Dessa forma, o fluxo do pipeline fica mais **organizado, reutilizável e fácil de visualizar**.

# %% [markdown]
# # SQL

# %% [markdown]
# ### SQLite + Python
# - **Base:** vendas.db
# - **Tabela:** vendas

# %%
import sqlite3
import pandas as pd

conexao = sqlite3.connect("dados/vendas.db")

# %% [markdown]
# #### Selecionar tudo

# %%
query = """
SELECT *
FROM vendas;
"""

df = pd.read_sql(query, conexao)

df
# Out:
#                    data   produto  quantidade  valor_unitario  valor_total
# 0   2026-08-01 00:00:00  Notebook           2            3500         7000
# 1   2026-08-01 00:00:00     Mouse           5              80          400
# 2   2026-08-02 00:00:00   Teclado           3             150          450
# 3   2026-08-02 00:00:00   Monitor           1            1200         1200
# 4   2026-08-03 00:00:00  Notebook           1            3500         3500
# 5   2026-08-03 00:00:00     Mouse           8              80          640
# 6   2026-08-04 00:00:00   Headset           4             250         1000
# 7   2026-08-04 00:00:00   Teclado           2             150          300
# 8   2026-08-05 00:00:00   Monitor           3            1200         3600
# 9   2026-08-05 00:00:00     Mouse           6              80          480
# 10  2026-08-06 00:00:00  Notebook           2            3500         7000
# 11  2026-08-06 00:00:00   Headset           3             250          750
# 12  2026-08-07 00:00:00   Teclado           5             150          750
# 13  2026-08-07 00:00:00   Monitor           1            1200         1200
# 14  2026-08-08 00:00:00     Mouse          10              80          800
# 15  2026-08-08 00:00:00  Notebook           1            3500         3500
# 16  2026-08-09 00:00:00   Headset           4             250         1000
# 17  2026-08-09 00:00:00   Teclado           3             150          450
# 18  2026-08-10 00:00:00   Monitor           2            1200         2400
# 19  2026-08-10 00:00:00     Mouse           7              80          560
# 20  2026-08-11 00:00:00  Notebook           2            3500         7000
# 21  2026-08-11 00:00:00   Headset           5             250         1250
# 22  2026-08-12 00:00:00   Teclado           4             150          600
# 23  2026-08-12 00:00:00     Mouse           8              80          640
# 24  2026-08-13 00:00:00   Monitor           1            1200         1200
# 25  2026-08-13 00:00:00  Notebook           2            3500         7000
# 26  2026-08-14 00:00:00   Headset           3             250          750
# 27  2026-08-14 00:00:00   Teclado           6             150          900
# 28  2026-08-15 00:00:00     Mouse           9              80          720
# 29  2026-08-15 00:00:00   Monitor           2            1200         2400
# 30  2026-08-16 00:00:00  Notebook           1            3500         3500
# 31  2026-08-16 00:00:00   Headset           4             250         1000
# 32  2026-08-17 00:00:00   Teclado           3             150          450
# 33  2026-08-17 00:00:00     Mouse           7              80          560
# 34  2026-08-18 00:00:00   Monitor           2            1200         2400
# 35  2026-08-18 00:00:00  Notebook           1            3500         3500
# 36  2026-08-19 00:00:00   Headset           5             250         1250
# 37  2026-08-19 00:00:00   Teclado           4             150          600
# 38  2026-08-20 00:00:00     Mouse           6              80          480
# 39  2026-08-20 00:00:00   Monitor           2            1200         2400
# 40  2026-08-21 00:00:00  Notebook           1            3500         3500
# 41  2026-08-21 00:00:00   Headset           3             250          750
# 42  2026-08-22 00:00:00   Teclado           5             150          750
# 43  2026-08-22 00:00:00     Mouse           8              80          640
# 44  2026-08-23 00:00:00   Monitor           2            1200         2400
# 45  2026-08-23 00:00:00  Notebook           1            3500         3500
# 46  2026-08-24 00:00:00   Headset           4             250         1000
# 47  2026-08-24 00:00:00   Teclado           3             150          450
# 48  2026-08-25 00:00:00     Mouse           7              80          560
# 49  2026-08-25 00:00:00   Monitor           2            1200         2400

# %% [markdown]
# #### Selecionar todas as vendas (colunas selecionadas)
# - data
# - produto
# - quantidade
# - valor_total

# %%
query = """
SELECT
    data,
    produto,
    quantidade,
    valor_total
FROM vendas;
"""

df = pd.read_sql(query, conexao)

df
# Out:
#                    data   produto  quantidade  valor_total
# 0   2026-08-01 00:00:00  Notebook           2         7000
# 1   2026-08-01 00:00:00     Mouse           5          400
# 2   2026-08-02 00:00:00   Teclado           3          450
# 3   2026-08-02 00:00:00   Monitor           1         1200
# 4   2026-08-03 00:00:00  Notebook           1         3500
# 5   2026-08-03 00:00:00     Mouse           8          640
# 6   2026-08-04 00:00:00   Headset           4         1000
# 7   2026-08-04 00:00:00   Teclado           2          300
# 8   2026-08-05 00:00:00   Monitor           3         3600
# 9   2026-08-05 00:00:00     Mouse           6          480
# 10  2026-08-06 00:00:00  Notebook           2         7000
# 11  2026-08-06 00:00:00   Headset           3          750
# 12  2026-08-07 00:00:00   Teclado           5          750
# 13  2026-08-07 00:00:00   Monitor           1         1200
# 14  2026-08-08 00:00:00     Mouse          10          800
# 15  2026-08-08 00:00:00  Notebook           1         3500
# 16  2026-08-09 00:00:00   Headset           4         1000
# 17  2026-08-09 00:00:00   Teclado           3          450
# 18  2026-08-10 00:00:00   Monitor           2         2400
# 19  2026-08-10 00:00:00     Mouse           7          560
# 20  2026-08-11 00:00:00  Notebook           2         7000
# 21  2026-08-11 00:00:00   Headset           5         1250
# 22  2026-08-12 00:00:00   Teclado           4          600
# 23  2026-08-12 00:00:00     Mouse           8          640
# 24  2026-08-13 00:00:00   Monitor           1         1200
# 25  2026-08-13 00:00:00  Notebook           2         7000
# 26  2026-08-14 00:00:00   Headset           3          750
# 27  2026-08-14 00:00:00   Teclado           6          900
# 28  2026-08-15 00:00:00     Mouse           9          720
# 29  2026-08-15 00:00:00   Monitor           2         2400
# 30  2026-08-16 00:00:00  Notebook           1         3500
# 31  2026-08-16 00:00:00   Headset           4         1000
# 32  2026-08-17 00:00:00   Teclado           3          450
# 33  2026-08-17 00:00:00     Mouse           7          560
# 34  2026-08-18 00:00:00   Monitor           2         2400
# 35  2026-08-18 00:00:00  Notebook           1         3500
# 36  2026-08-19 00:00:00   Headset           5         1250
# 37  2026-08-19 00:00:00   Teclado           4          600
# 38  2026-08-20 00:00:00     Mouse           6          480
# 39  2026-08-20 00:00:00   Monitor           2         2400
# 40  2026-08-21 00:00:00  Notebook           1         3500
# 41  2026-08-21 00:00:00   Headset           3          750
# 42  2026-08-22 00:00:00   Teclado           5          750
# 43  2026-08-22 00:00:00     Mouse           8          640
# 44  2026-08-23 00:00:00   Monitor           2         2400
# 45  2026-08-23 00:00:00  Notebook           1         3500
# 46  2026-08-24 00:00:00   Headset           4         1000
# 47  2026-08-24 00:00:00   Teclado           3          450
# 48  2026-08-25 00:00:00     Mouse           7          560
# 49  2026-08-25 00:00:00   Monitor           2         2400

# %% [markdown]
# #### Filtrar vendas

# %%
query = """
SELECT *
FROM vendas
WHERE valor_total > 500;
"""

df = pd.read_sql(query, conexao)

df
# Out:
#                    data   produto  quantidade  valor_unitario  valor_total
# 0   2026-08-01 00:00:00  Notebook           2            3500         7000
# 1   2026-08-02 00:00:00   Monitor           1            1200         1200
# 2   2026-08-03 00:00:00  Notebook           1            3500         3500
# 3   2026-08-03 00:00:00     Mouse           8              80          640
# 4   2026-08-04 00:00:00   Headset           4             250         1000
# 5   2026-08-05 00:00:00   Monitor           3            1200         3600
# 6   2026-08-06 00:00:00  Notebook           2            3500         7000
# 7   2026-08-06 00:00:00   Headset           3             250          750
# 8   2026-08-07 00:00:00   Teclado           5             150          750
# 9   2026-08-07 00:00:00   Monitor           1            1200         1200
# 10  2026-08-08 00:00:00     Mouse          10              80          800
# 11  2026-08-08 00:00:00  Notebook           1            3500         3500
# 12  2026-08-09 00:00:00   Headset           4             250         1000
# 13  2026-08-10 00:00:00   Monitor           2            1200         2400
# 14  2026-08-10 00:00:00     Mouse           7              80          560
# 15  2026-08-11 00:00:00  Notebook           2            3500         7000
# 16  2026-08-11 00:00:00   Headset           5             250         1250
# 17  2026-08-12 00:00:00   Teclado           4             150          600
# 18  2026-08-12 00:00:00     Mouse           8              80          640
# 19  2026-08-13 00:00:00   Monitor           1            1200         1200
# 20  2026-08-13 00:00:00  Notebook           2            3500         7000
# 21  2026-08-14 00:00:00   Headset           3             250          750
# 22  2026-08-14 00:00:00   Teclado           6             150          900
# 23  2026-08-15 00:00:00     Mouse           9              80          720
# 24  2026-08-15 00:00:00   Monitor           2            1200         2400
# 25  2026-08-16 00:00:00  Notebook           1            3500         3500
# 26  2026-08-16 00:00:00   Headset           4             250         1000
# 27  2026-08-17 00:00:00     Mouse           7              80          560
# 28  2026-08-18 00:00:00   Monitor           2            1200         2400
# 29  2026-08-18 00:00:00  Notebook           1            3500         3500
# 30  2026-08-19 00:00:00   Headset           5             250         1250
# 31  2026-08-19 00:00:00   Teclado           4             150          600
# 32  2026-08-20 00:00:00   Monitor           2            1200         2400
# 33  2026-08-21 00:00:00  Notebook           1            3500         3500
# 34  2026-08-21 00:00:00   Headset           3             250          750
# 35  2026-08-22 00:00:00   Teclado           5             150          750
# 36  2026-08-22 00:00:00     Mouse           8              80          640
# 37  2026-08-23 00:00:00   Monitor           2            1200         2400
# 38  2026-08-23 00:00:00  Notebook           1            3500         3500
# 39  2026-08-24 00:00:00   Headset           4             250         1000
# 40  2026-08-25 00:00:00     Mouse           7              80          560
# 41  2026-08-25 00:00:00   Monitor           2            1200         2400

# %% [markdown]
# #### Ordenar vendas

# %%
query = """
SELECT *
FROM vendas
ORDER BY valor_total DESC;
"""

df = pd.read_sql(query, conexao)

df
# Out:
#                    data   produto  quantidade  valor_unitario  valor_total
# 0   2026-08-01 00:00:00  Notebook           2            3500         7000
# 1   2026-08-06 00:00:00  Notebook           2            3500         7000
# 2   2026-08-11 00:00:00  Notebook           2            3500         7000
# 3   2026-08-13 00:00:00  Notebook           2            3500         7000
# 4   2026-08-05 00:00:00   Monitor           3            1200         3600
# 5   2026-08-03 00:00:00  Notebook           1            3500         3500
# 6   2026-08-08 00:00:00  Notebook           1            3500         3500
# 7   2026-08-16 00:00:00  Notebook           1            3500         3500
# 8   2026-08-18 00:00:00  Notebook           1            3500         3500
# 9   2026-08-21 00:00:00  Notebook           1            3500         3500
# 10  2026-08-23 00:00:00  Notebook           1            3500         3500
# 11  2026-08-10 00:00:00   Monitor           2            1200         2400
# 12  2026-08-15 00:00:00   Monitor           2            1200         2400
# 13  2026-08-18 00:00:00   Monitor           2            1200         2400
# 14  2026-08-20 00:00:00   Monitor           2            1200         2400
# 15  2026-08-23 00:00:00   Monitor           2            1200         2400
# 16  2026-08-25 00:00:00   Monitor           2            1200         2400
# 17  2026-08-11 00:00:00   Headset           5             250         1250
# 18  2026-08-19 00:00:00   Headset           5             250         1250
# 19  2026-08-02 00:00:00   Monitor           1            1200         1200
# 20  2026-08-07 00:00:00   Monitor           1            1200         1200
# 21  2026-08-13 00:00:00   Monitor           1            1200         1200
# 22  2026-08-04 00:00:00   Headset           4             250         1000
# 23  2026-08-09 00:00:00   Headset           4             250         1000
# 24  2026-08-16 00:00:00   Headset           4             250         1000
# 25  2026-08-24 00:00:00   Headset           4             250         1000
# 26  2026-08-14 00:00:00   Teclado           6             150          900
# 27  2026-08-08 00:00:00     Mouse          10              80          800
# 28  2026-08-06 00:00:00   Headset           3             250          750
# 29  2026-08-07 00:00:00   Teclado           5             150          750
# 30  2026-08-14 00:00:00   Headset           3             250          750
# 31  2026-08-21 00:00:00   Headset           3             250          750
# 32  2026-08-22 00:00:00   Teclado           5             150          750
# 33  2026-08-15 00:00:00     Mouse           9              80          720
# 34  2026-08-03 00:00:00     Mouse           8              80          640
# 35  2026-08-12 00:00:00     Mouse           8              80          640
# 36  2026-08-22 00:00:00     Mouse           8              80          640
# 37  2026-08-12 00:00:00   Teclado           4             150          600
# 38  2026-08-19 00:00:00   Teclado           4             150          600
# 39  2026-08-10 00:00:00     Mouse           7              80          560
# 40  2026-08-17 00:00:00     Mouse           7              80          560
# 41  2026-08-25 00:00:00     Mouse           7              80          560
# 42  2026-08-05 00:00:00     Mouse           6              80          480
# 43  2026-08-20 00:00:00     Mouse           6              80          480
# 44  2026-08-02 00:00:00   Teclado           3             150          450
# 45  2026-08-09 00:00:00   Teclado           3             150          450
# 46  2026-08-17 00:00:00   Teclado           3             150          450
# 47  2026-08-24 00:00:00   Teclado           3             150          450
# 48  2026-08-01 00:00:00     Mouse           5              80          400
# 49  2026-08-04 00:00:00   Teclado           2             150          300

# %% [markdown]
# #### Calcular faturamento total

# %%
query = """
SELECT SUM(valor_total) AS fat_total
FROM vendas;
"""

df = pd.read_sql(query, conexao)

df
# Out:
#    fat_total
# 0      91530

# %% [markdown]
# #### Faturamento por produto

# %%
query = """
SELECT
    produto,
    SUM(valor_total) AS faturamento
FROM vendas
GROUP BY produto
ORDER BY faturamento DESC;
"""

df = pd.read_sql(query, conexao)

df
# Out:
#     produto  faturamento
# 0  Notebook        49000
# 1   Monitor        21600
# 2   Headset         8750
# 3     Mouse         6480
# 4   Teclado         5700

# %% [markdown]
# #### Quantidade de vendas por produto

# %%
query = """
SELECT
    produto,
    COUNT(*) AS quantidade_vendas
FROM vendas
GROUP BY produto
ORDER BY quantidade_vendas DESC;
"""

df = pd.read_sql(query, conexao)

df
# Out:
#     produto  quantidade_vendas
# 0     Mouse                 11
# 1   Teclado                 10
# 2  Notebook                 10
# 3   Monitor                 10
# 4   Headset                  9

# %% [markdown]
# #### Fechar a conexão

# %%
conexao.close()
